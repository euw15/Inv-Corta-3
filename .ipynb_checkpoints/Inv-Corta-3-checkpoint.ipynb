# %% [markdown]
# # Investigacion corta#3
#
# ## Reconocimiento de patrones
# ## Edward Umana
# ## Alejandro Bermudez
#
# ## Junio 18

# %% [markdown]
# # En qué consiste este método?

# %% [markdown]
# #### Reinforcement learning:
#
# El reinforcement learning (RL), expone que mediante el ensayo y error la máquina va comprendiendo cuales es la mejor decisión para obtener un resultado de calidad. Eso se puede comparar a como se le enseña a un niño que cierto comportamiento es correcto, tan sencillo con premiarlo. Asimismo, el niño empieza a eliminar las conductas que no son premiadas. De igual manera hace la máquina sólo conserva las acciones que la llevan al éxito.

# %% [markdown]
# RL se modela generalmente como un proceso de decisión de Markov (MDP) como se ilustra en la imagen de abajo.

# %% [markdown]
# ![title](algori.PNG)

# %% [markdown]
# ## Ejemplo
# Vamos a describir un ejemplo simple para observar los parametros y sus definiciones en el siguiente escenario:

# %% [markdown]
# Para este escenario a un bebe se le entrega un control remoto para el televisor en la casa (Environment). En simples terminos, el bebe (Agente) primero observara y construira su propia representation del ambiente (state).
# Entonces el curioso bebe tomara cierta accion como golpear el control remoto (action) y observar como responde el televisor (next-state). Como un televisor que no responde es aburrido, el bebe no le gusta (receiving a negative reward) y tomara mejores acciones que lo conduzcan a un resultado similar (updating the policy) y viceversa. El bebe repitira el proceso hasta que el/ella encuentre un policy (que hacer en diferentes circuntancias) para que el/ella este feliz con (maximizando el total (discounted) recompensas).

# %% [markdown]
# 1. **Agent**: Un agente toma las acciones
# 2. **Action (A)**: Es el conjunto de todo los posibles movimientos que el agente puede hacer
# 3. **Discount factor**:
# 4. **Environment**: El mundo donde se mueve el agente.
# 5. **State (S)**: Un especifico lugar y momento. Puede ser la actual situacion retornada por el ambiente o cualquier futura situacion.
# 6. **Reward (R)**: Es la realimentacion de la cual se mide el logro o el fracaso de la cciones del agente.
# 7. **Policy (π)**: Es la estrategia que el agente emplea para determinar la proxima accion basada en el estado actual.
# 8. **Value (V)**:
# 9. **Q-value or action-value (Q)**: Es similar al value, excepto que toma un parametro extra, la accion actual.

# %% [markdown]
# **State:** El objetivo es que el estado resuma la información relevante que pueda serle de utilidad al agente, y nada más, de forma que ésta sea fácilmente manejable.

# %% [markdown]
# En la ilustracion de abajo se puede observar las componentes mas importantes del RL:

# %% [markdown]
# ![title](components.PNG)

# %% [markdown]
# # Cuales son los casos de uso.

# %% [markdown]
# Resources management in computer clusters

# %% [markdown]
# Traffic Light Control

# %% [markdown]
# Robotics

# %% [markdown]
# Web System Configuration

# %% [markdown]
# Chemistry

# %% [markdown]
# Ejemplos
#
# Una buena manera de introducir el aprendizaje por refuerzo es considerar algunos de los ejemplos y posibles aplicaciones que han guiado su desarrollo:
#
# 1. Un maestro de ajedrez hace un movimiento. La elección es informada tanto por planificación | anticipando posibles respuestas y contestar {respuestas] y mediante juicios intuitivos inmediatos de la conveniencia de posiciones particulares y se mueve
# 2. Un controlador adaptativo ajusta los parámetros de la operación de una petrolera en tiempo real. El controlador optimiza el rendimiento / costo / calidad tradeo? basado en costos marginales específicos sin atenerse estrictamente a los puntos de ajuste Originalmente sugerido por ingenieros humanos.
# 3. Un becerro de gacela lucha hasta sus pies minutos después de nacer. Media hora más tarde se ejecuta a 30 millas por hora.
# 4.  Phil prepara su desayuno. Cuando se examina de cerca, incluso esto aparentemente La actividad mundana se revela como una compleja red de comportamiento condicional y meta de enclavamiento {relaciones sub-objetivo: caminar hacia el armario, abrir seleccionando una caja de cereal, luego alcanzándola, agarrándola y recuperándola. Se requieren otras secuencias de comportamiento complejas, afinadas e interactivas para Obtener un tazón, una cuchara y una jarra de leche. Cada paso involucra una serie de ojos. Movimientos para obtener información y para orientar el alcance y la locomoción. Continuamente se hacen juicios rápidos sobre cómo llevar los objetos. o si es mejor transportar a algunos de ellos a la mesa del comedor antes obteniendo otros. Cada paso está guiado por objetivos, como agarrar una cuchara, o llegar al refrigerador, y está al servicio de otros objetivos, como tener La cuchara para comer una vez que el cereal está preparado y de obtener finalmente. alimento.
# 5. Un robot móvil decide si debe entrar en una nueva sala en busca de Más basura para recoger o comenzar a tratar de encontrar su camino de regreso a su batería. estación de recarga. Toma su decisión en función de la rapidez y facilidad con que ha sido capaz de encontrar el cargador en el pasado.

# %% [markdown]
# # Mayores desafíos

# %% [markdown]
# Sin embargo, los problemas a los que nos enfrentamos en el mundo real pueden ser extremadamente complicados de muchas maneras diferentes y, por lo tanto, un algoritmo RL típico no tiene ninguna pista que resolver.
# Los métodos de aprendizaje por refuerzo, y en concreto Q-learning, pero también algunas limitaciones que merece la pena
# comentar:

# %% [markdown]
# 1. Requieren un estudio del dominio del problema, para modelar correctamente los estados y las recompensas. Si el dominio es difícil de representar de forma que el agente pueda entenderlo, puede que sea complicado implementar este tipo de métodos.

# %% [markdown]
# 2. Son eficaces en problemas pequeños. Si no hay demasiados estados, estos se van a revisitar más a menudo, lo que actualizará la tabla Q a menudo, llegando antes a la solución óptima.

# %% [markdown]
# 3. **Intercambio entre exploración y explotación** Para obtener una gran cantidad de recompensas, un agente de aprendizaje por refuerzo debe preferir las acciones que ha intentado en el pasado y que han demostrado ser eficaces para producir una recompensa. Pero para descubrir qué acciones son éstas, tiene que seleccionar acciones que no haya probado antes. El agente tiene que explotar lo que ya sabe para obtener una recompensa, mientras que también tiene que explorar para hacer mejores selecciones de acción en el futuro.

# %% [markdown]
# #  Cómo se compara a otros métodos?

# %% [markdown]
# | # | NO SUPERVISADO   | SUPERVISADO   | POR REFUERZO   |
# |------|------|------|------|
# |   1  |  Los algoritmos aprenden similitudes con los nombres y, por extensión, pueden detectar lo inverso y realizar la detección de anomalías al reconocer lo que es inusual o diferente.  | Datos de información que son etiquetados por el humano previamente.|Las acciones se basan en recompensas a corto y largo plazo, como la cantidad de calorías que ingieres o la cantidad de tiempo que sobrevives.
# |   2  | Se le proporciona una gran cantidad de información, no necesita que los algoritmos tengas datos estructurados. | Requieren un conjunto de datos etiquetado,Esas etiquetas se utilizan para "supervisar" y corregir el algoritmo.   | El aprendizaje por refuerzo se puede considerar como aprendizaje supervisado en un entorno de retroalimentación escasa.   |
# |   3  | Muestran las características de alguna cosa u objeto sin casi la presencia del humano.| La máquina aprenda por sí sola a identificar las imágenes, por ejemplo se etiqueta miles de imágenes de gatos y perros. En el futuro el sistema deberá identificar y diferenciar los gatos de los perros,   | La decisión de aprendizaje es dependiente, por lo que asignamos etiquetas a las secuencias de decisiones dependientes   |
# |   4  | El sistema organizara esta información e identificará el objeto o la cosa, e indicará que es.| La máquina aprenda por sí sola a identificar las imágenes   | La idea es que aprenda por medio de la experiencia previa.   |
# |   5  | Ej. Reconocimiento de objetos, emociones en diferentes rostros humanos | Ej. Es el reconocimiento de voz o de escritura, como lo es, la de una firma.   | Ej. Juego de ajedrez   |

# %% [markdown]
# # La propiedad de Markov

# %% [markdown]
# Otra característica que deben tener los estados es la llamada propiedad de Markov, que se refiere a la propiedad de un estado por la cual las recompensas que se puedan obtener en un futuro a partir de él tomando distintas acciones sucesivas sólo dependen de ese estado, y no de los anteriores. Por ejemplo, en un determinado momento de una partida de ajedrez, las recompensas futuras solo dependen del estado actual del tablero, no de cómo se ha llegado
# hasta él.

# %% [markdown]
# #  Proceso de decisión de Markov (MDP)

# %% [markdown]
# Una tarea de aprendizaje por refuerzo que satisface la propiedad de Markov para todos
# los estados se conoce como proceso de decisión de Markov, o MDP. Si el número de acciones
# y estados son finitos, entonces se llaman procesos de decisión de Markov finitos, o FMDP.
# Estos son particularmente importantes en la teoría del aprendizaje por refuerzo.
# Un FMDP particular queda definido por sus conjuntos de estados y acciones. Dados un
# estado *s* y una acción *a*, la probabilidad de cada siguiente estado *s′* es

# %% [markdown]
# ![title](recompensa.PNG)

# %% [markdown]
# De igual manera, dado un estado *s* y una acción *a*, el valor esperado de la siguiente recompensa será:

# %% [markdown]
# ![title](probabilidad.PNG)

# %% [markdown]
# Estas dos cantidades especifican la cualidad más importante de los FMDP.

# %% [markdown]
# # Q-learning

# %% [markdown]
# Uno de los más importantes avances en el aprendizaje por refuerzo fue el desarrollo del
# algoritmo Q-learning. En su forma más simple, se actualiza el valor de la función Q en un
# paso, de la siguiente manera:

# %% [markdown]
# ![title](Q_learning.PNG)

# %% [markdown]
# En este caso, la función Q aprendida se aproxima directamente a Q*, la función óptima, independientemente de la política seguida. Esto simplifica enormemente el análisis del algoritmo y las pruebas de convergencia sobre él. El único requisito que debe cumplir la política para garantizar la convergencia del algoritmo es que todos los pares estado-acción deben seguir siendo actualizados de manera continua. El algoritmo Q-learning tiene la siguiente forma:

# %% [markdown]
# ![title](algoritmo.PNG)

# %% [markdown]
# # La tabla Q

# %% [markdown]
# En el algoritmo vemos que se modifican los valores de la función Q pero, ¿cómo se maneja realmente esta información?
# Estos datos se organizan en forma de tabla, en la que se irá añadiendo información sobre los nuevos estados y acciones que se vayan explorando. Así, cada fila de la misma corresponde a un estado distinto, y cada columna almacena información sobre el valor de las acciones. En concreto, el elemento (i, j) de la tabla representa el valor de realizar desde el estado *si* la acción *aj*.
# Implementar y manejar esta tabla correctamente se convertirá en una prioridad de aquí al final del proyecto pues es donde reside todo el conocimiento del agente sobre las decisiones que puede y debe tomar.
# A continuación se muestra un ejemplo:
# .

# %% [markdown]
# ![title](tabla.PNG)

# %%
Equilibrio exploración-explotación

# %% [markdown]
# También vemos que en el algoritmo se menciona una “política que dependa de Q”, lo cual quiere decir que el agente debe tomar sus acciones aprovechando lo que ha aprendido previamente. Uno podría pensar que la mejor manera de afrontar una situación pasada esescoger la opción que mejor resultado le haya dado hasta el momento, pero esto puede no serasí. Puede ser que, aunque alguna acción de un buen resultado, haya otra aún inexploradaque, a la larga, le haga obtener al agente una recompensa mayor. Una de las cualidades, por tanto, que debe tener la política elegida, es que mantenga un equilibrio entre la explotación del conocimiento ya aprendido, y la exploración de nuevas soluciones, para comprobar si efectivamente hay mejores acciones disponibles o no. Un ejemplo de política que cumple esto, que será muy utilizada de aquí en adelante, es la política ε-greedy, que consiste en que en cada momento de decidir qué acción realizar, hay una probabilidad ε de que se realice una acción aleatoria, y si no, se escoge la mejor acción disponible

# %% [markdown]
# # Estado actual

# %% [markdown]
# Deep Reinforment Learning es la combinación de Reinforment Learning y Deep Learning. Este campo de investigación ha permitido ampliar la gama de tareas con desiciones complejas. Ampliando asi el paradigma de problemas y areas en las que se puede utilizar.
#
# En estos casos la función de valor Q o la función Policy se calcula utilizando redes neuranales

# %% [markdown]
# ![title](atari.png)

# %% [markdown]
# ## Deep Mind
#
# ![title](dims.jpg)

# %% [markdown]
# Pioneros en el tema de Deep Reinforment Learning
#
# Ejemplos de Exito:
# - AlphaStar
# - AlphaGo

# %% [markdown]
# ## OpenAI
#
# ![title](openai.png)

# %% [markdown]
# De igual manera utilizando algoritmos de Deep Reinforment Learning para resolver sus aproacches
#
# Ejemplos de Exito:
#
# - Gym
# - RoboSumo

# %% [markdown]
# ## Importancia de una buena selección del reward
#
# Ejemplo de una mala elección del rewards
#
# https://www.youtube.com/watch?v=tlOIHko8ySg

# %% [markdown]
# # Ejemplos

# %% [markdown]
# Vamos a enseñarle a jugar Blackjack a nuestro agente.

# %% [markdown]
# Entre las bibliotecas a utilizar, entre ellas encontraremos "gym"
#
# Gym es una biblioteca de OpenAI que brinda una serie de ambientes ya prediseñados
# con los cuales se puede interactuar de una manera muy amigable. Con ambientes que permiten
# desde juegos de Atari, Robots o ambientes para enseñarle a caminar a humanos.

# %%
import sys
import gym
import numpy as np
from collections import defaultdict

# %% [markdown]
# Importamos el ambiente de Blackjack gracias a OpenGym, el cual provee el ambiente.

# %%
env = gym.make('Blackjack-v0')

# %% [markdown]
# Aprendamos primero a utilizar el ambiente

# %%
state = env.reset()
action = env.action_space.sample()
next_state, reward, done, info = env.step(action)
print("El estado es: ",next_state)
print("Reward: ", reward)
# Out:
# El estado es:  (15, 10, False)
# Reward:  1.0

# %% [markdown]
# Ahora podemos implementar nuestro algoritmo de RL utilizando Q-Learning.

# %% [markdown]
# Primero vamos a configurar algunos hiper parametros que ya conocemos

# %%
#Numero de episodios
num_episodes = 500000 

#Learning rate
alpha = 0.01

#El gamma
gamma=1.0

#Epsilon: utilizado para el policy aleatorio
epsilon_start=1.0
epsilon_decay_rate=.95
epsilon_min=0.05

numActions = 2

# %% [markdown]
# Luego inicializamos nuestra matriz Q

# %%
##Q representa el Estimate action value funtion
Q = defaultdict(lambda: np.zeros(numActions))

# %% [markdown]
# Iteramos por la cantidad de episodios que deseamos realizar

# %%
##Iteramos por todos los episodios
for episode_index in range(1, num_episodes):
    
    ##Generamos un episodio
    episode = []
    state = env.reset()
    epsilon = epsilon_start
    
    while True:
        ##Desicion de la accion a realizar utilizando Epsilon greedy policy 
        if(state in Q):
            epsilon = max(epsilon*epsilon_decay_rate, epsilon_min)
            temp_policy = np.ones(numActions) * epsilon / numActions
            mostLikelyindex = np.argmax(Q[state])
            temp_policy[mostLikelyindex] = 1 - epsilon + (epsilon / numActions)
            action = np.random.choice(np.arange(numActions), p=temp_policy)
        else:
            action = env.action_space.sample()
        
        ##agregamos el estado al episodio, y seguimos con otro estado
        next_state, reward, done, info = env.step(action)
        episode.append((state, action, reward))
        state = next_state
        if done:
            break
    
    states, actions, rewards = zip(*episode)
    
    ##Update Q
    for actionIndex, state in enumerate(states):
        tmp_Q = Q[state][actions[actionIndex]] 
        Q[state][actions[actionIndex]] = tmp_Q + alpha*(sum(rewards[actionIndex:]) - tmp_Q)
    
# determine the policy corresponding to the final action-value function estimate
policy = dict((k,np.argmax(v)) for k, v in Q.items())

# %% [markdown]
#  Utilizamos un poco de ayuda visual de
#  https://github.com/udacity/deep-reinforcement-learning/blob/master/monte-carlo/plot_utils.py
#  que posee unos metodos que facilitan la visualización del polocy y de la función Q para este problema

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

def plot_blackjack_values(V):

    def get_Z(x, y, usable_ace):
        if (x,y,usable_ace) in V:
            return V[x,y,usable_ace]
        else:
            return 0

    def get_figure(usable_ace, ax):
        x_range = np.arange(11, 22)
        y_range = np.arange(1, 11)
        X, Y = np.meshgrid(x_range, y_range)
        
        Z = np.array([get_Z(x,y,usable_ace) for x,y in zip(np.ravel(X), np.ravel(Y))]).reshape(X.shape)

        surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.cm.coolwarm, vmin=-1.0, vmax=1.0)
        ax.set_xlabel('Player\'s Current Sum')
        ax.set_ylabel('Dealer\'s Showing Card')
        ax.set_zlabel('State Value')
        ax.view_init(ax.elev, -120)

    fig = plt.figure(figsize=(20, 20))
    ax = fig.add_subplot(211, projection='3d')
    ax.set_title('Usable Ace')
    get_figure(True, ax)
    ax = fig.add_subplot(212, projection='3d')
    ax.set_title('No Usable Ace')
    get_figure(False, ax)
    plt.show()

def plot_policy(policy):

    def get_Z(x, y, usable_ace):
        if (x,y,usable_ace) in policy:
            return policy[x,y,usable_ace]
        else:
            return 1

    def get_figure(usable_ace, ax):
        x_range = np.arange(11, 22)
        y_range = np.arange(10, 0, -1)
        X, Y = np.meshgrid(x_range, y_range)
        Z = np.array([[get_Z(x,y,usable_ace) for x in x_range] for y in y_range])
        surf = ax.imshow(Z, cmap=plt.get_cmap('Pastel2', 2), vmin=0, vmax=1, extent=[10.5, 21.5, 0.5, 10.5])
        plt.xticks(x_range)
        plt.yticks(y_range)
        plt.gca().invert_yaxis()
        ax.set_xlabel('Player\'s Current Sum')
        ax.set_ylabel('Dealer\'s Showing Card')
        ax.grid(color='w', linestyle='-', linewidth=1)
        divider = make_axes_locatable(ax)
        cax = divider.append_axes("right", size="5%", pad=0.1)
        cbar = plt.colorbar(surf, ticks=[0,1], cax=cax)
        cbar.ax.set_yticklabels(['0 (STICK)','1 (HIT)'])
            
    fig = plt.figure(figsize=(15, 15))
    ax = fig.add_subplot(121)
    ax.set_title('Usable Ace')
    get_figure(True, ax)
    ax = fig.add_subplot(122)
    ax.set_title('No Usable Ace')
    get_figure(False, ax)
    plt.show()

# %%
# obtain the corresponding state-value function
V = dict((k,np.max(v)) for k, v in Q.items())

# plot the state-value function
plot_blackjack_values(V)

# %%
# plot the policy
plot_policy(policy)

# %% [markdown]
# ## Segundo Ejemplo

# %%
import gym
import numpy as np
import math
from collections import deque

# %% [markdown]
# Definimos los hiperparametros

# %%
buckets = (1, 1, 6, 12,)
n_episodes = 100
n_win_ticks= 195
min_alpha=0.1
min_epsilon=0.1
gamma=1.0
ada_divisor=25

# %% [markdown]
# Definimos el ambiente en el que queremos trabajar

# %%
 env = gym.make('CartPole-v0')

# %% [markdown]
# Al igual que en el ejemplo anterior inicializamos nuestro Q-Table

# %%
Q = np.zeros(buckets + (env.action_space.n,))

# %% [markdown]
# Discretizamos el ambiente para obtener los valores que nos interesa del ambiente

# %%
def discretize(obs):
        upper_bounds = [env.observation_space.high[0], 0.5, env.observation_space.high[2], math.radians(50)]
        lower_bounds = [env.observation_space.low[0], -0.5, env.observation_space.low[2], -math.radians(50)]
        ratios = [(obs[i] + abs(lower_bounds[i])) / (upper_bounds[i] - lower_bounds[i]) for i in range(len(obs))]
        new_obs = [int(round((buckets[i] - 1) * ratios[i])) for i in range(len(obs))]
        new_obs = [min(buckets[i] - 1, max(0, new_obs[i])) for i in range(len(obs))]
        return tuple(new_obs)

# %% [markdown]
# Iteramos por la cantidad de episodios que deseamos realizar

# %%
for e in range(n_episodes):
    # As states are continuous, discretize them into buckets
    current_state = discretize(env.reset())

    # Get adaptive learning alpha and epsilon decayed over time
    alpha = max(min_alpha, min(1.0, 1.0 - math.log10((e + 1) / ada_divisor)))
    epsilon = max(min_epsilon, min(1, 1.0 - math.log10((e + 1) / ada_divisor)))
    done = False
    i = 0
            
    while not done:
        # Render environment
        env.render()

        # Choose action according to greedy policy and take it
        action = env.action_space.sample() if (np.random.random() <= epsilon) else np.argmax(Q[current_state])
        obs, reward, done, _ = env.step(action)
        new_state = discretize(obs)

        # Update Q-Table
        Q[current_state][action] += alpha * (reward + gamma * np.max(Q[new_state]) - Q[current_state][action])
        current_state = new_state
        i += 1
